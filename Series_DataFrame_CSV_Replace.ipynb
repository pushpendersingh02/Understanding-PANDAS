# %% [markdown]
# # Series

# %%
import pandas as pd

# %%
a=[10,20,30]
b=pd.Series(a, index=['apples','balls','cats'],dtype='float', name='Grocery')
print(b)
# Out:
# apples    10.0
# balls     20.0
# cats      30.0
# Name: Grocery, dtype: float64

# %% [markdown]
# ## DataFrame

# %%
dic={"Ram":[23,22,45,78,65],"Sita":[65,24,75,29,66],"Laxman":[96,44,76,88,56,]}

dic1=[[23,22,45,78,65],[65,24,75,29,66],[96,44,76,88,56,]]

# %%
dic
var = pd.DataFrame(dic)
var
# Out:
#    Ram  Sita  Laxman
# 0   23    65      96
# 1   22    24      44
# 2   45    75      76
# 3   78    29      88
# 4   65    66      56

# %%
var1 = pd.DataFrame(dic,columns=['Sita'])
var1
# Out:
#    Sita
# 0    65
# 1    24
# 2    75
# 3    29
# 4    66

# %%
var2 = pd.DataFrame(dic1)
var2
# Out:
#     0   1   2   3   4
# 0  23  22  45  78  65
# 1  65  24  75  29  66
# 2  96  44  76  88  56

# %%
dic3=[pd.Series([1,2,3,4,5]),pd.Series([10,20,30,40,50]),pd.Series([10,20,30,4,5])]
var3=pd.DataFrame(dic3, index=['A','B','C'])
var3
# Out:
#     0   1   2   3   4
# A   1   2   3   4   5
# B  10  20  30  40  50
# C  10  20  30   4   5

# %%
var3["Total"]=var3[0]+var3[1]+var3[2]+var3[3]+var3[4]
var3["Result"]=var3['Total']>=33
var3
# Out:
#     0   1   2   3   4  Total  Result
# A   1   2   3   4   5     15   False
# B  10  20  30  40  50    150    True
# C  10  20  30   4   5     69    True

# %%
var3
# Out:
#     0   1   2   3   4  Total  Result
# A   1   2   3   4   5     15   False
# B  10  20  30  40  50    150    True
# C  10  20  30   4   5     69    True

# %%
var4=pd.DataFrame([22,32,11])
var3[4]=[22,33,11]
var3
# Out:
#     0   1   2   3   4  Total  Result
# A   1   2   3   4  22     15   False
# B  10  20  30  40  33    150    True
# C  10  20  30   4  11     69    True

# %%
var3.pop('Total')
# Out:
# A     15
# B    150
# C     69
# Name: Total, dtype: int64

# %%
var3
# Out:
#     0   1   2   3   4  Result
# A   1   2   3   4  22   False
# B  10  20  30  40  33    True
# C  10  20  30   4  11    True

# %%
var3.to_csv("Test_CSV.csv",index=False)

# %%
var4.to_csv("Test_CSV.csv",index=False)

# %%
var4=pd.read_csv("D:\\Business Analyst\\Python\\Pandas\\Test_CSV.csv",skiprows=1)

# %%
var4
# Out:
#    22
# 0  32
# 1  11

# %%
dict = {"Student": ["Arnav", "Neha",
					"Priya", "Rahul"],
		"Marks_Sub1": [85, 92, 78, 83],
        "Marks_Sub2": [44, 90, 59, 69],
        "Marks_Sub3": [85, 78, 78, 55],
        "Marks_Sub4": [49, 92, 98, 83],
        "Marks_Sub5": [69, 47, 33, 99],
		"Sports": ["Cricket", "Volleyball", 
				"Hockey", "Badminton"]}

df = pd.DataFrame(dict)
df['Total']=df['Marks_Sub1']+df['Marks_Sub2']+df['Marks_Sub3']+df['Marks_Sub4']+df['Marks_Sub5']
df['Percentage']=df['Total']/5
display(df)
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          78          92          47
# 2   Priya          78          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv1=df.to_csv('Trial.csv',index=False)

# %%
 df1=pd.read_csv('D:\\Business Analyst\\Python\\Pandas\\Trial.csv')

# %%
df1
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          78          92          47
# 2   Priya          78          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %% [markdown]
# # PANDAS CSV Function

# %%
csv=pd.read_csv('D:\\Business Analyst\\Python\\Pandas\\Trial.csv')
csv
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          78          92          47
# 2   Priya          78          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
csv.columns
# Out:
# Index(['Student', 'Marks_Sub1', 'Marks_Sub2', 'Marks_Sub3', 'Marks_Sub4',
#        'Marks_Sub5', 'Sports', 'Total', 'Percentage'],
#       dtype='object')

# %%
csv.describe()
# Out:
#        Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5       Total  \
# count    4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
# mean    84.500000   65.500000   74.000000   80.500000   62.000000  366.500000
# std      5.802298   19.295941   13.089436   21.886069   28.774989   32.521788
# min     78.000000   44.000000   55.000000   49.000000   33.000000  332.000000
# 25%     81.750000   55.250000   72.250000   74.500000   43.500000  342.500000
# 50%     84.000000   64.000000   78.000000   87.500000   58.000000  367.500000
# 75%     86.750000   74.250000   79.750000   93.500000   76.500000  391.500000
# max     92.000000   90.000000   85.000000   98.000000   99.000000  399.000000
#
#        Percentage
# count    4.000000
# mean    73.300000
# std      6.504358
# min     66.400000
# 25%     68.500000
# 50%     73.500000
# 75%     78.300000
# max     79.800000

# %%
csv.head(2)
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          78          92          47
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8

# %%
csv.tail(1)
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 3   Rahul          83          69          55          83          99
#
#       Sports  Total  Percentage
# 3  Badminton    389        77.8

# %%
csv[1:3]
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 1    Neha          92          90          78          92          47
# 2   Priya          78          59          78          98          33
#
#        Sports  Total  Percentage
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2

# %%
display(type(csv))
# Out:
# pandas.core.frame.DataFrame

# %%
csv.index.array
# Out:
# <NumpyExtensionArray>
# [0, 1, 2, 3]
# Length: 4, dtype: int64

# %%
csv.to_numpy()
# Out:
# array([['Arnav', 85, 44, 85, 49, 69, 'Cricket', 332, 66.4],
#        ['Neha', 92, 90, 78, 92, 47, 'Volleyball', 399, 79.8],
#        ['Priya', 78, 59, 78, 98, 33, 'Hockey', 346, 69.2],
#        ['Rahul', 83, 69, 55, 83, 99, 'Badminton', 389, 77.8]],
#       dtype=object)

# %%
import numpy as np
v = np.asarray(csv)
v
# Out:
# array([['Arnav', 85, 44, 85, 49, 69, 'Cricket', 332, 66.4],
#        ['Neha', 92, 90, 78, 92, 47, 'Volleyball', 399, 79.8],
#        ['Priya', 78, 59, 78, 98, 33, 'Hockey', 346, 69.2],
#        ['Rahul', 83, 69, 55, 83, 99, 'Badminton', 389, 77.8]],
#       dtype=object)

# %% [markdown]
# ### Sorting

# %%
csv.sort_index(axis=0, ascending= False)
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 3   Rahul          83          69          55          83          99
# 2   Priya          78          59          78          98          33
# 1    Neha          92          90          78          92          47
# 0   Arnav          85          44          85          49          69
#
#        Sports  Total  Percentage
# 3   Badminton    389        77.8
# 2      Hockey    346        69.2
# 1  Volleyball    399        79.8
# 0     Cricket    332        66.4

# %%
csv.sort_index(axis=1, ascending= False)
# Out:
#    Total Student      Sports  Percentage  Marks_Sub5  Marks_Sub4  Marks_Sub3  \
# 0    332   Arnav     Cricket        66.4          69          49          85
# 1    399    Neha  Volleyball        79.8          47          92          78
# 2    346   Priya      Hockey        69.2          33          98          78
# 3    389   Rahul   Badminton        77.8          99          83          55
#
#    Marks_Sub2  Marks_Sub1
# 0          44          85
# 1          90          92
# 2          59          78
# 3          69          83

# %%
csv['Student'][1]='Ayushi'
csv
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12084\2415474761.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   csv['Student'][1]='Ayushi'
# ...

# %%
csv.loc[1,'Student']='Mansi'
csv
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1   Mansi          92          90          78          92          47
# 2   Priya          78          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv.loc[1,'Total']
# Out:
# 399

# %%
csv.loc[[0,1],['Student','Sports','Percentage']]
# Out:
#   Student      Sports  Percentage
# 0   Arnav     Cricket        66.4
# 1   Mansi  Volleyball        79.8

# %%
csv.loc[:,['Student','Sports','Percentage']]
# Out:
#   Student      Sports  Percentage
# 0   Arnav     Cricket        66.4
# 1   Mansi  Volleyball        79.8
# 2   Priya      Hockey        69.2
# 3   Rahul   Badminton        77.8

# %%
csv.iloc[0,6]
# Out:
# 'Cricket'

# %%
csv.iloc[[0,1],[0,6,7,8]]
# Out:
#   Student      Sports  Total  Percentage
# 0   Arnav     Cricket    332        66.4
# 1   Mansi  Volleyball    399        79.8

# %%
csv.drop('Marks_Sub5',axis=1)
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4      Sports  Total  \
# 0   Arnav          85          44          85          49     Cricket    332
# 1   Mansi          92          90          78          92  Volleyball    399
# 2   Priya          78          59          78          98      Hockey    346
# 3   Rahul          83          69          55          83   Badminton    389
#
#    Percentage
# 0        66.4
# 1        79.8
# 2        69.2
# 3        77.8

# %%
csv.drop(1,axis=0)
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 2   Priya          78          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#       Sports  Total  Percentage
# 0    Cricket    332        66.4
# 2     Hockey    346        69.2
# 3  Badminton    389        77.8

# %% [markdown]
# # Replace

# %%
csv1=pd.read_csv('D:\\Business Analyst\\Python\\Pandas\\Trial.csv')
csv1
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          78          92          47
# 2   Priya          78          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv1.replace(to_replace=78, value=22)
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          22          92          47
# 2   Priya          22          59          22          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv1.replace([22,85,83,92],00)
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav           0          44           0          49          69
# 1    Neha           0          90          78           0          47
# 2   Priya          78          59          78          98          33
# 3   Rahul           0          69          55           0          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv1.replace("[A-Za-z]",'Python',regex=True)
# Out:
#                           Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  \
# 0  PythonPythonPythonPythonPython          85          44          85
# 1        PythonPythonPythonPython          92          90          78
# 2  PythonPythonPythonPythonPython          78          59          78
# 3  PythonPythonPythonPythonPython          83          69          55
#
#    Marks_Sub4  Marks_Sub5                                             Sports  \
# 0          49          69         PythonPythonPythonPythonPythonPythonPython
# 1          92          47  PythonPythonPythonPythonPythonPythonPythonPyth...
# 2          98          33               PythonPythonPythonPythonPythonPython
# 3          83          99  PythonPythonPythonPythonPythonPythonPythonPyth...
#
#    Total  Percentage
# 0    332        66.4
# 1    399        79.8
# 2    346        69.2
# 3    389        77.8

# %%
csv1.replace("[a-z]",'Python',regex=True)
# Out:
#                      Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  \
# 0  APythonPythonPythonPython          85          44          85          49
# 1        NPythonPythonPython          92          90          78          92
# 2  PPythonPythonPythonPython          78          59          78          98
# 3  RPythonPythonPythonPython          83          69          55          83
#
#    Marks_Sub5                                             Sports  Total  \
# 0          69              CPythonPythonPythonPythonPythonPython    332
# 1          47  VPythonPythonPythonPythonPythonPythonPythonPyt...    399
# 2          33                    HPythonPythonPythonPythonPython    346
# 3          99  BPythonPythonPythonPythonPythonPythonPythonPython    389
#
#    Percentage
# 0        66.4
# 1        79.8
# 2        69.2
# 3        77.8

# %%
csv1.replace({'Student':'[A-Z]'},100,regex=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12084\1888541385.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   csv1.replace({'Student':'[A-Z]'},100,regex=True)
#    Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0      100          85          44          85          49          69
# 1      100          92          90          78          92          47
# 2      100          78          59          78          98          33
# 3      100          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv1.replace(78,method='ffill')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12084\2917079126.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   csv1.replace(78,method='ffill')
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          85          92          47
# 2   Priya          92          59          85          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv1.replace(78,method='bfill')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12084\2209727711.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   csv1.replace(78,method='bfill')
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          55          92          47
# 2   Priya          83          59          55          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv1.replace(78,method='ffill',limit=1)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12084\1965962384.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   csv1.replace(78,method='ffill',limit=1)
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          85          92          47
# 2   Priya          92          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %% [markdown]
# ### Replacing using Inplace

# %%
# Inplace will not create the copy, rather it will change in the root variable
csv1
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          78          92          47
# 2   Priya          78          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8

# %%
csv1.replace(78,method='ffill',limit=1, inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12084\2819598077.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   csv1.replace(78,method='ffill',limit=1, inplace=True)

# %%
csv1
# Out:
#   Student  Marks_Sub1  Marks_Sub2  Marks_Sub3  Marks_Sub4  Marks_Sub5  \
# 0   Arnav          85          44          85          49          69
# 1    Neha          92          90          85          92          47
# 2   Priya          92          59          78          98          33
# 3   Rahul          83          69          55          83          99
#
#        Sports  Total  Percentage
# 0     Cricket    332        66.4
# 1  Volleyball    399        79.8
# 2      Hockey    346        69.2
# 3   Badminton    389        77.8
